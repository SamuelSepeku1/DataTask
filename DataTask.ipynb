# %% [markdown]
# INTRODUCTION
#
# This is a simple analysis done on an automobile database with data basing on the 1980s collections
#
# Source

# %% [markdown]
# IMPORTING THE REQUIRED LIBRARIES FOR ANALYSIS

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# LOADING THE DATASET

# %%
pd.set_option('display.max_columns',None)

data=pd.read_csv("Automobile_data.csv")
data
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  \
# 0            two  convertible          rwd           front        88.6
# ...

# %% [markdown]
# EXPLORATORY DATA ANALYSIS
#
# Here simple oprations and functions are executed on the process of trying to understand the structure of the dataset, data types and other features.

# %%
#Displaying the first 10 rows
data.head(10)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
# 5          2                 ?         audi       gas        std          two
# 6          1               158         audi       gas        std         four
# 7          1                 ?         audi       gas        std         four
# 8          1               158         audi       gas      turbo         four
# 9          0                 ?         audi       gas      turbo          two
#
#     body-style drive-wheels engine-location  wheel-base  length  width  \
# ...

# %%
#Displaying the dimensions of the dataset(rows, columns)
data.shape
# Out:
# (205, 26)

# %%
# Displaying the features or the columns of the dataset
data.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='str')

# %%
# Displaying the short summary of the dataset 
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    str
#  2   make               205 non-null    str
#  3   fuel-type          205 non-null    str
#  4   aspiration         205 non-null    str
#  5   num-of-doors       205 non-null    str
#  6   body-style         205 non-null    str
#  7   drive-wheels       205 non-null    str
#  8   engine-location    205 non-null    str
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    str
#  15  num-of-cylinders   205 non-null    str
#  16  engine-size        205 non-null    int64
# ...

# %%
data.isna().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# DATA PREPROCESSING
#
# This involves structuring data into an approptiate format (data type) removing duplicates and filling null values.

# %%
# replace the value "?" with "" across all columns for proper data formatting
data=data.replace('?','')

target_columns=['normalized-losses','bore','stroke','horsepower','peak-rpm','price']
for x in target_columns:
    data[x]=pd.to_numeric(data[x])
    print(f"data type of {x} is:",data[x].dtype)

#rechecking data types for all columns in the dataset
print("\n\n",data.dtypes)
# Out:
# data type of normalized-losses is: float64
# data type of bore is: float64
# data type of stroke is: float64
# data type of horsepower is: float64
# data type of peak-rpm is: float64
# data type of price is: float64
#
#
#  symboling              int64
# normalized-losses    float64
# make                     str
# fuel-type                str
# aspiration               str
# num-of-doors             str
# body-style               str
# drive-wheels             str
# engine-location          str
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type              str
# num-of-cylinders         str
# engine-size            int64
# fuel-system              str
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# ...

# %%
#checking for null values after replacement and changing data types
data.isna().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          0
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
#filling null values in the dataset
a=data['normalized-losses'].median()
data['normalized-losses']=data['normalized-losses'].fillna(a,inplace=True)

b=data['bore'].median()
data['bore']=data['bore'].fillna(b,inplace=True)

c=data['stroke'].median()
data['stroke']=data['stroke'].fillna(c,inplace=True)

x=data['horsepower'].median()
data['horsepower']=data['horsepower'].fillna(x,inplace=True)

y=data['peak-rpm'].median()
data['peak-rpm']=data['peak-rpm'].fillna(y,inplace=True)

z=data['price'].median()
data['price']=data['price'].fillna(z,inplace=True)
# Out:
# /tmp/ipykernel_24277/1910074672.py:3: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   data['normalized-losses']=data['normalized-losses'].fillna(a,inplace=True)
# ...

# %%
#checking for null values after imputation
data.isna().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
data.drop_duplicates()
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3              115.0  alfa-romero       gas        std
# 1            3              115.0  alfa-romero       gas        std
# 2            1              115.0  alfa-romero       gas        std
# 3            2              164.0         audi       gas        std
# 4            2              164.0         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 200         -1               95.0        volvo       gas        std
# 201         -1               95.0        volvo       gas      turbo
# 202         -1               95.0        volvo       gas        std
# 203         -1               95.0        volvo    diesel      turbo
# 204         -1               95.0        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  \
# 0            two  convertible          rwd           front        88.6
# ...

# %%
#statistical summary after data cleaning
data.describe()
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  205.000000         205.000000  205.000000  205.000000  205.000000
# mean     0.834146         120.600000   98.756585  174.049268   65.907805
# std      1.245307          31.805105    6.021776   12.337289    2.145204
# min     -2.000000          65.000000   86.600000  141.100000   60.300000
# 25%      0.000000         101.000000   94.500000  166.300000   64.100000
# 50%      1.000000         115.000000   97.000000  173.200000   65.500000
# 75%      2.000000         137.000000  102.400000  183.100000   66.900000
# max      3.000000         256.000000  120.900000  208.100000   72.300000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  205.000000   205.000000   205.000000  205.000000  205.000000
# mean    53.724878  2555.565854   126.907317    3.329366    3.256098
# std      2.443522   520.680204    41.642693    0.270858    0.313634
# ...

# %% [markdown]
# DATA VISUALIZATION
